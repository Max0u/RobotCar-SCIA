# %%
import cv2, os
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as mpplot
import nvi_utils

# %%
file_path = "/home/fabien/Projet/AutoCar/resources/records_good/frame_9_gas_0.4_dir_0.0.jpg"
real_path = "../../resources/2018_06_13_16_44/frame_1585_gas_0.0_dir_0.0.jpg"

# %%
image = mpimg.imread(real_path)
image = nvi_utils.resize(image)
steering_angle = 0
mpplot.imshow(image)

# %%
im = mpimg.imread(file_path)
im = nvi_utils.resize(im)
mpplot.imshow(im)

# %%
resim = nvi_utils.preprocess(im)
mpplot.imshow(resim)

# %%
imhsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
mpplot.imshow(imhsv)

# %%
bright = mpimg.imread(bright_path)
bright = bright[60:-20,:,:]
mpplot.imshow(bright)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-12f9efbf21e2> in <module>()
# ----> 1 bright = mpimg.imread(bright_path)
#       2 bright = bright[60:-20,:,:]
#       3 mpplot.imshow(bright)
#
# NameError: name 'bright_path' is not defined

# %%
bright = autobright(bright, 300)
mpplot.imshow(bright)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-44e52831889b> in <module>()
# ----> 1 bright = autobright(bright, 300)
#       2 mpplot.imshow(bright)
#
# NameError: name 'autobright' is not defined

# %%
obsc = mpimg.imread(obsc_path)
obsc = obsc[60:-20,:,:]
mpplot.imshow(obsc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-42b3f490664b> in <module>()
# ----> 1 obsc = mpimg.imread(obsc_path)
#       2 obsc = obsc[60:-20,:,:]
#       3 mpplot.imshow(obsc)
#
# NameError: name 'obsc_path' is not defined

# %%
obsc = autobright(obsc, 150)
mpplot.imshow(obsc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c7b0d824a8a7> in <module>()
# ----> 1 obsc = autobright(obsc, 150)
#       2 mpplot.imshow(obsc)
#
# NameError: name 'autobright' is not defined

# %%
res = nvi_utils.preprocess(image)
mpplot.imshow(res)

# %%
res1, steering_angle = nvi_utils.random_flip(image, steering_angle)
mpplot.imshow(res1)

# %%
res2, steering_angle = nvi_utils.random_translate(image, steering_angle, 100, 10)
mpplot.imshow(res2)

# %%
res3 = nvi_utils.random_shadow(image)
mpplot.imshow(res3)

# %%
res4 = nvi_utils.random_brightness(image)
mpplot.imshow(res4)

# %%
hsv = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
hsv[:,:,2] = np.minimum(hsv[:,:,2]*9, 255)
res5 = cv2.cvtColor(hsv, cv2.COLOR_HSV2RGB)
mpplot.imshow(res5)

# %%
res6 = cv2.cvtColor(res5, cv2.COLOR_RGB2HLS)
res6[:,:,2] *= 1
res6 = cv2.cvtColor(res6, cv2.COLOR_HLS2RGB)
mpplot.imshow(res6)

# %%
res7 = np.array(255 * (res6 / 255)**0.65, dtype=np.uint8)
mpplot.imshow(res7)

# %%
res = nvi_utils.preprocess(res5)
mpplot.imshow(res)

# %%
res = nvi_utils.preprocess(res6)
mpplot.imshow(res)

# %%
res = nvi_utils.preprocess(res7)
mpplot.imshow(res)
